# %% [markdown]
# <h1 style="text-align:center;">ESCUELA POLITECNICA NACIONAL</h1>
# <h2 style="text-align:center;">FACULTAD DE INGENIERIA DE SISTEMAS</h2>
# <h3 style="text-align:center;">INGENIERIA EN CIENCIAS DE LA COMPUTACION</h3>

# %% [markdown]
# **PERIODO ACADEMICO:** 2025-B
#
# **ASIGNATURA:** ICCD412 Métodos Numéricos
#
# **GRUPO:** GR1
#
# **FECHA DE ENTREGA LIMITE:** 05/11/2025
#
# **ALUMNO:** Carrion Mauricio
#
# **TAREA 4**

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.optimize import bisect

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### a) [0,1]

# %%
r1 = bisect(f = lambda x : x**3 - 7*x**2 + 14*x - 6, a = 0, b = 1, xtol = 10**(-2), maxiter = 20)
print(f'El resultado de la biseccion da la raíz {r1}')
# Out:
# El resultado de la biseccion da la raíz 0.5859375

# %% [markdown]
# #### b) [1 , 3.2]

# %%
r2 = bisect(f = lambda x : x**3 - 7*x**2 + 14*x - 6, a = 1, b = 3.2, xtol = 10**(-2), maxiter = 20)
print(f'El resultado de la biseccion da la raíz {r2}')
# Out:
# El resultado de la biseccion da la raíz 3.0023437500000005

# %% [markdown]
# #### c) [3.2 , 4]

# %%
r3 = bisect(f = lambda x : x**3 - 7*x**2 + 14*x - 6, a = 3.2, b = 4, xtol = 10**(-2), maxiter = 20)
print(f'El resultado de la biseccion da la raíz {r3}')
# Out:
# El resultado de la biseccion da la raíz 3.4187500000000006

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### a) Dibuje las gráficas para $y = x$ y $y = sin(x)$
#
# Primer graficamos la función $y = x$:

# %%
X = np.linspace(0, 10, 1000)
Y1 = X

plt.plot(X, Y1, label='y = x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de y = x')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Grafica de y = sin(x):

# %%
Y2 = np.sin(X)

plt.plot(X, Y2, label='y = sin(x)', color='orange')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de y = sin(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ####  b) Use el método de bisección para encontrar una aproximación dentro de $10^{-5}$ para un valor el primer valor positivo de $x$ tal que $x = 2sin(x)$.

# %%
r = bisect(f=lambda x: x - 2*math.sin(x), a=1, b=2, xtol=10**(-5), maxiter=100)
print(f'El primer valor positivo de x tal que x = 2*sin(x) es aproximadamente: {r}')
# Out:
# El primer valor positivo de x tal que x = 2*sin(x) es aproximadamente: 1.8955001831054688

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### a) Dibuje las gráficas para $y = x$ y $y = tan(x)$
# Primer graficamos la función $y = x$:

# %%
X = np.linspace(0, 10, 1000)
Y1 = X

plt.plot(X, Y1, label='y = x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de y = x')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Graficamos la función $y = tan(x)$:

# %%
Y2 = []
X_filtered = []
for x in X:
    if abs(math.cos(x)) > 0.01:
        X_filtered.append(x)
        Y2.append(math.tan(x))

plt.plot(X_filtered, Y2, label='y = tan(x)', color='orange')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de y = tan(x)')
plt.legend()
plt.grid(True)
plt.ylim(-10, 10)
plt.show()

# %% [markdown]
# ####  b) Use el método de bisección para encontrar una aproximación dentro de $10^{-5}$ para un valor el primer valor positivo de $x$ tal que $x = tan(x)$.

# %%
r = bisect(f=lambda x: x - math.tan(x), a=4.4, b=4.6, xtol=10**(-5), maxiter=100)
print(f'El primer valor positivo de x tal que x = tan(x) es aproximadamente: {r}')
# Out:
# El primer valor positivo de x tal que x = tan(x) es aproximadamente: 4.493414306640625

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### a) Dibuje las gráficas para $y = x^2 - 1$ y $y = e^{1 - x^2}$
#
# Empezamos graficando la función $y = x^2 - 1$:

# %%
X = np.linspace(-10, 10, 100)
Y = [(lambda x : x**2 - 1)(x) for x in X]

plt.plot(X, Y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafica de $y = x^2 - 1$')
ax = plt.gca()
ax.set_ylim([-2.5, 22.5])
ax.set_xlim([-10, 10])
plt.grid(True)
plt.show()

# %% [markdown]
# Y seguido de esto gráfica para la función $y = e^{1 - x^2}$:

# %%
Y = [(lambda x : math.exp(1 - x**2))(x) for x in X]

plt.plot(X, Y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafica de $y = e^{1 - x^2}$')
ax = plt.gca()
ax.set_ylim([-2.5, 5])
ax.set_xlim([-10, 10])
plt.grid(True)
plt.show()

# %% [markdown]
# ####  b) Use el método de bisección para encontrar una aproximación dentro de $10^{-3}$ para un valor (-2, 0) con $x^2 - e^{1 - x^2} - 1$.
#
# Por bisección tenemos:

# %%
r = bisect(f = lambda x : x**2 - math.exp(1 - x**2) - 1, a = -2, b = 0, xtol = 10**(-3), maxiter = 20)
print(f'El resultado de la biseccion da la raíz {r}')
# Out:
# El resultado de la biseccion da la raíz -1.2509765625

# %% [markdown]
# # 2. Ejercicios aplicados

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Como dicta el ejercicio el 0.01 cm se puede interpretar como el error absoluto que se puede tolerar al calcular $h$.
#
# Entonces empezamos reemplazando los valores en la ecuación original, tal que:
#
# $$12.4 = 10[0.5 \pi (1)^2 - 1^2 \arcsin{\frac{h}{1}} - h(1^2 - h^2)^{\frac{1}{2}}]$$
#
# Utlizaremos método de bisección para resolverlo de manera mas sencilla. La anterior ecuación se tiene que igualar a cero, para así, calcular las raices que h puede tener.
#
# $$0 = 10[0.5 \pi (1)^2 - 1^2 \arcsin{\frac{h}{1}} - h(1^2 - h^2)^{\frac{1}{2}}] - 12.4$$
#
# Implementa en código con una función lambda.

# %%
r = bisect(f = lambda x : 10 * (0.5 * math.pi - math.asin(x) - x * (1 - x**2)**0.5) - 12.4, a = 0, b = 1, xtol = 0.01, maxiter = 20)
print(f'La profundidad del agua (h) es aproximadamente: {r} cm')
# Out:
# La profundidad del agua (h) es aproximadamente: 0.1640625 cm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Se necesita de métodos numéricos para resolverlo por ello en 0.01 segundos es el error absoluto admisible será nuestra raíz. Reemplazamos los datos dados en el enunciado para la fórmula, tal que la ecuación esté respecto al tiempo.
#
# $0 = 300 - \frac{(25)(9.81)}{0.1} t + \frac{(25)^2(9.81)}{(0.1)^2} (1 - e^{\frac{-(0.1)t}{25}})$
#
# Sutituimos adicionalmente a $s(t) = 0$ porque la función representa la altura en la que el objeto se encuentra en cierto momento, pero el problema nos pide el tiempo para cuando toque el suelo. Tomando como el sistema de referencia para el eje y el suelo, entonces la altura es cero.
#
# Implementamos la función bisección:

# %%
r = bisect(f = lambda x : 300 - (25*9.81*x)/0.1 + (625*9.81)*(1 - math.exp(-(0.1)*x/25))/0.1**2, a = 7, b = 8, xtol = 0.01, maxiter = 20)
print(f'El tiempo en tocar el suelo (t) es: {r} segundos')
# Out:
# El tiempo en tocar el suelo (t) es: 7.8671875 segundos

# %% [markdown]
# # 3. Ejercicios teóricos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Implementamos bisección con los parámetros ya que no se encuentra el teorema en la tarea.

# %%
r = bisect(f = lambda x : x**3 - x - 1, a = 1, b = 2, xtol = 10**(-4), maxiter = 20)
print(f'El resultado de la biseccion da la raíz {r}')
# Out:
# El resultado de la biseccion da la raíz 1.32476806640625
