# %% [markdown]
# <h1 style="text-align:center;">ESCUELA POLITECNICA NACIONAL</h1>
# <h2 style="text-align:center;">FACULTAD DE INGENIERIA DE SISTEMAS</h2>
# <h3 style="text-align:center;">INGENIERIA EN CIENCIAS DE LA COMPUTACION</h3>

# %% [markdown]
# **PERIODO ACADEMICO:** 2025-B
#
# **ASIGNATURA:** ICCD412 Métodos Numéricos
#
# **GRUPO:** GR1
#
# **FECHA DE ENTREGA LIMITE:** 05/11/2025
#
# **ALUMNO:** Carrion Mauricio
#
# **TAREA 2**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) $𝑝 = 𝜋, 𝑝∗ = 22/7$
#
#   $|p-p*| = |𝜋-22/7| = 1,2644 * 10^-3$
#
#   $\frac{|p-p*|}{|p|} = \frac{|𝜋-22/7|}{|𝜋|} = 4,024 * 10^-4$
#
# b) $𝑝 = 𝜋, 𝑝∗ = 3,1416$
#
#   $|p-p*| = |𝜋-3,1416| = 7,346* 10^-6$
#
#   $\frac{|p-p*|}{|p|} = \frac{|𝜋-3,1416|}{|𝜋|} = 2,338 * 10^-6$
#
# c) $𝑝 = e, 𝑝∗ = 2,718$
#
#   $|p-p*| = |e-2,718| = 2,818* 10^-4$
#
#   $\frac{|p-p*|}{|p|} = \frac{|e-2,718|}{|e|} = 1,036 * 10^-4$
#
# d) $𝑝 = \sqrt{2}, 𝑝∗ = 1,414$
#
#   $|p-p*| = |\sqrt{2}-1,414| = 2,135* 10^-4$
#
#   $\frac{|p-p*|}{|p|} = \frac{|\sqrt{2}-1,414|}{|\sqrt{2}|} = 1,51 * 10^-4$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) $𝑝 = e^10, 𝑝∗ = 22000$
#
#   $|p-p*| = |e^10 - 22000| = 26,465$
#
#   $\frac{|p-p*|}{|p|} = \frac{|e^10 - 22000|}{|e^10|} = 1,2 * 10^-3$
#
# b) $𝑝 = 10^𝜋, 𝑝∗ = 1400$
#
#   $|p-p*| = |10^𝜋 - 1400| = 14,544$
#
#   $\frac{|p-p*|}{|p|} = \frac{|10^𝜋 - 1400|}{|10^𝜋|} = 0,0104$
#
# c) $𝑝 = 8!, 𝑝∗ = 39900$
#
#   $|p-p*| = |8!-39900| = 420$
#
#   $\frac{|p-p*|}{|p|} = \frac{|8!-39900|}{|8!|} = 0,01$
#
# d) $𝑝 = 9!, 𝑝∗ = \sqrt{18𝜋}(\frac{9}{e})^9$
#
#   $|p-p*| = |9! - \sqrt{18𝜋}\frac{9}{e}^9| = 3343,12$
#
#   $\frac{|p-p*|}{|p|} = \frac{|9! - \sqrt{18𝜋}\frac{9}{e}^9|}{|9!|} = 9,21 * 10^-3$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) $𝜋$
#
#  $\frac{|p-p*|}{|p|} = \frac{|𝜋-p*|}{|𝜋|} = 10^-4$
#
#  $\frac{𝜋-p*}{𝜋} = 10^-4$ y $\frac{𝜋-p*}{𝜋} = -10^-4$
#
#  $p* = 3,141278494$ ó $p* = 3,141906813$
#
#  $p * ∈ [3,141278494 ,3,141906813]$
#
# b) $e$
#
#  $\frac{|p-p*|}{|p|} = \frac{|e-p*|}{|e|} = 10^-4$
#
#  $\frac{e-p*}{e} = 10^-4$ y $\frac{e-p*}{e} = -10^-4$
#
#  $p* = 2,71801$ ó $p* = 2,718553657$
#
#  $p * ∈ [2,71801 ,2,718553657]$
#
# c) $\sqrt{2}$
#
#  $\frac{|p-p*|}{|p|} = \frac{|\sqrt{2}-p*|}{|\sqrt{2}|} = 10^-4$
#
#  $\frac{\sqrt{2}-p*}{\sqrt{2}} = 10^-4$ y $\frac{\sqrt{2}-p*}{\sqrt{2}} = -10^-4$
#
#  $p* = 1,414072141$ ó $p* = 1,414354984$
#
#  $p * ∈ [1,41407214 ,1,414354984]$
#
# d) $\sqrt{7}$
#
#  $\frac{|p-p*|}{|p|} = \frac{|\sqrt{7}-p*|}{|\sqrt{7}|} = 10^-4$
#
#  $\frac{\sqrt{7}-p*}{\sqrt{7}} = 10^-4$ y $\frac{\sqrt{7}-p*}{\sqrt{7}} = -10^-4$
#
#  $p* = 1,91273989$ ó $p* = 1,913122476$
#
#  $p * ∈ [1,91273989 ,1,913122476]$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) $\frac{\frac{13}{14}-\frac{5}{7}}{2e-5,4}$
#
#   $p = 0,58606*10^1 ; p= 0,586*10^1$
#
#   $|p-p*|= 6 * 10^-4$ y $\frac{|p-p*|}{|p|} = 1,024 * 10^-4$
#
# b) $-10𝜋+6e-\frac{3}{61}$
#
#   $p = -0,15155*10^2 ; p= -0,152*10^2$
#
#   $|p-p*|= 0x045$ y $\frac{|p-p*|}{|p|} = 2x9693 * 10^-4$
#
#
# c) $\frac{2}{9} * \frac{9}{11}$
#
#   $p = 0,18182 ; p= 0,182$
#
#   $|p-p*|= 1,8*10^-4 $ y $\frac{|p-p*|}{|p|} = 9,899 * 10^-4$
#
#
# d) $\frac{\sqrt{13}+\sqrt{11}}{\sqrt{13}-\sqrt{11}}$
#
#   $p = ,0,23958*10^2 ; p= 0,240*10^2$
#
#   $|p-p*|= 0,042$ y $\frac{|p-p*|}{|p|} = 1,753 * 10^-3$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) $4[arctan \frac{1}{2} + arctan \frac{1}{3}]$
#
#   $|𝜋-p*| = 3,98* 10^-3$
#
#   $\frac{|𝜋-p*|}{|𝜋|} = 1,267 * 10^-3$
#
# b) $16arctan \frac{1}{5} - 4 arctan \frac{1}{236}$
#
#   $|𝜋-p*| = 2,83* 10^-5$
#
#   $\frac{|𝜋-p*|}{|𝜋|} = 9,03 * 10^-6$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) $Σ(5,n=0)\frac{1}{!n}$
#
#   $Σ(5,n=0)\frac{1}{!n} = 2,716666667 = p*$
#
#   $|e-p*| = 1,615* 10^-3$
#
#   $\frac{|e-p*|}{|e|} = 5,94 * 10^-4$
#
# b) $Σ(10,n=0)\frac{1}{!n}$
#
#   $Σ(10,n=0)\frac{1}{!n} = 2,718281801 = p*$
#
#   $|e-p*| = 2,731* 10^-8$
#
#   $\frac{|e-p*|}{|e|} = 1,004 * 10^-8$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Las fórmulas son:
#
# $$
# x = \frac{x_0 y_1 - x_1 y_0}{y_1 - y_0}
# $$
#
# y
#
# $$
# x = x_0 - \frac{(x_1 - x_0)y_0}{y_1 - y_0}
# $$
#
# a) Use los datos $(x_0, y_0) = (1.31, 3.24)$ y $(x_1, y_1) = (1.93, 5.76)$ y la aritmética de redondeo de tres dígitos para calcular la intersección con $x$ de ambas maneras.
#
# * Primer método
#
#     $x = \frac{x_0 y_1 - x_1 y_0}{y_1 - y_0} = 0.5128571429$
#
# * Segundo método
#
#     $x = x_0 - \frac{(x_1 - x_0)y_0}{y_1 - y_0} = 0.5128571429$
#
# **¿Cuál método es mejor y por que?**
#
# El segundo ya que este tiene menor cantidad de operaciones, por lo tanto tiene menor costo computacional.
